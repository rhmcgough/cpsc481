# %% [markdown]
# Classwork 1:
#
# * Prompt TitanGPT to get the course requirements for the AI-ML Concentration
# ```
# The B.S. in Computer Science, Artificial Intelligence and Machine Learning Concentration course requirements are published in the CSUF University Catalog. 1
#
# Artificial Intelligence and Machine Learning Concentration (15 units) 1
# Required (6 units) 1
# CPSC 375 – Introduction to Data Science and Big Data (3) 1
# CPSC 483 – Introduction to Machine Learning (3) 1
#
# AI/ML Concentration Elective (choose 1 course = 3 units) 1
# CPSC 254 – Applied Artificial Intelligence (3) 1
# CPSC 454 – Cloud Computing and Security (3) 1
# CPSC 474 – Parallel and Distributed Computing (3) 1
# CPSC 476 – Edge AI: Principles and Practices (3) 1
# CPSC 479 – Introduction to High Performance Computing (3) 1
# CPSC 488 – Natural Language Processing (3) 1
#
# Computer Science Electives (6 units) 1
# You also complete 6 additional units of CS electives (with a maximum of 3 units lower-division allowed). 1 The catalog lists the approved elective options (including courses such as CPSC 349, 352, 386, 411/411A, 431, 439, 440, 449, 455, 456, 458, 459, 462, 463, 464, 466, 484, 485, 486, 499, EGGN 495, and selected MATH electives). 1
#
# Official catalog page (most direct source): https://catalog.fullerton.edu/preview_program.php?catoid=101&poid=48132 1
# ```
#
# * Prompt TitanGPT to get the total number of Concentration units
# ```
# The AI/ML concentration totals 15 units (6 units required + 3 units from the AI/ML elective list + 6 units of CS electives).
# ```

# %% [markdown]
# Classwork 2:
